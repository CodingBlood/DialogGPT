# %% [markdown]
# # Setting up Pytorch
#
# - pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# - python3.10 --version //Python 3.10.19
# - updated cuda driver to latest stable version

# %%
import torch
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0))
# Out:
# Torch: 2.5.1+cu121
# CUDA available: True
# Device: NVIDIA GeForce RTX 4050 Laptop GPU

# %% [markdown]
# # Fetching DataSet from Kaggle
#
# - https://www.kaggle.com/datasets/Cornell-University/movie-dialog-corpus/code
# - https://www.kaggle.com/datasets/phiitm/marvel-cinematic-universe-dialogue-dataset/code (Later)

# %%
import kagglehub

# Define your custom local path
my_local_path = "./../artifacts/data_ingetion"

# Download the entire dataset to that specific folder
# 1. handle: The Kaggle identifier ("owner/dataset")
# 2. output_dir: Your specific local destination
path = kagglehub.dataset_download(
    handle="rajathmc/cornell-moviedialog-corpus",
    output_dir=my_local_path
)

print(f"Dataset downloaded to: {path}")
# Out:
# ...
# 100%|██████████| 9.58M/9.58M [00:03<00:00, 2.68MB/s]
# Extracting files...
# Dataset downloaded to: ./../artifacts/data_ingetion
